# %%
import matplotlib.pyplot as plt

# Data from your DenseNet121 model output
metrics = {
    'accuracy': [0.651, 0.735, 0.753, 0.754, 0.768, 0.784, 0.774, 0.803, 0.813, 0.810, 0.813, 0.814, 0.838, 0.830, 0.847, 0.853, 0.846, 0.854, 0.857, 0.848, 0.854, 0.862, 0.866, 0.857, 0.807],
    'f1_m': [0.655, 0.737, 0.739, 0.749, 0.754, 0.776, 0.760, 0.797, 0.808, 0.799, 0.785, 0.800, 0.838, 0.835, 0.847, 0.847, 0.845, 0.854, 0.855, 0.849, 0.856, 0.861, 0.869, 0.860, 0.798],
    'loss': [4.323, 0.767, 0.684, 0.669, 0.660, 0.608, 0.630, 0.569, 0.510, 0.541, 0.529, 0.519, 0.452, 0.454, 0.426, 0.415, 0.433, 0.407, 0.391, 0.413, 0.393, 0.385, 0.364, 0.394, 0.506],
    'precision_m': [0.677, 0.781, 0.801, 0.808, 0.831, 0.847, 0.844, 0.856, 0.864, 0.860, 0.877, 0.867, 0.868, 0.866, 0.877, 0.868, 0.872, 0.880, 0.875, 0.875, 0.877, 0.882, 0.887, 0.878, 0.879],
    'recall_m': [0.637, 0.701, 0.688, 0.699, 0.694, 0.719, 0.696, 0.747, 0.762, 0.749, 0.716, 0.746, 0.810, 0.807, 0.820, 0.827, 0.820, 0.830, 0.835, 0.826, 0.837, 0.842, 0.853, 0.844, 0.739],
    'val_accuracy': [0.733, 0.730, 0.785, 0.739, 0.766, 0.782, 0.818, 0.766, 0.785, 0.752, 0.793, 0.793, 0.755, 0.796, 0.818, 0.782, 0.791, 0.796, 0.788, 0.793, 0.788, 0.802, 0.796, 0.785, 0.785],
    'val_f1_m': [0.740, 0.724, 0.775, 0.730, 0.714, 0.765, 0.800, 0.757, 0.766, 0.725, 0.773, 0.789, 0.759, 0.788, 0.810, 0.787, 0.765, 0.794, 0.786, 0.782, 0.770, 0.808, 0.778, 0.731, 0.769],
    'val_loss': [0.765, 0.693, 0.583, 0.707, 0.641, 0.571, 0.543, 0.616, 0.635, 0.724, 0.614, 0.571, 0.622, 0.591, 0.553, 0.698, 0.712, 0.584, 0.597, 0.622, 0.629, 0.623, 0.689, 0.666, 0.615],
}

epochs = range(1, 26)

# Plot accuracy, F1 score, precision, recall, and loss
plt.figure(figsize=(14, 10))

# Subplot 1: Accuracy
plt.subplot(2, 3, 1)
plt.plot(epochs, metrics['accuracy'], label='Train Accuracy')
plt.plot(epochs, metrics['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy over Epochs')
plt.legend()

# Subplot 2: F1 Score
plt.subplot(2, 3, 2)
plt.plot(epochs, metrics['f1_m'], label='Train F1 Score')
plt.plot(epochs, metrics['val_f1_m'], label='Validation F1 Score')
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('F1 Score over Epochs')
plt.legend()

# Subplot 3: Precision
plt.subplot(2, 3, 3)
plt.plot(epochs, metrics['precision_m'], label='Train Precision')
plt.plot(epochs, metrics['recall_m'], label='Recall')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.title('Precision and Recall over Epochs')
plt.legend()

# Subplot 4: Loss
plt.subplot(2, 3, 4)
plt.plot(epochs, metrics['loss'], label='Train Loss')
plt.plot(epochs, metrics['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss over Epochs')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the graph comparison
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']

# Values from the provided image (previous dataset)
train_previous = [77.41, 87.78, 74.12, 76.84]
val_previous = [72.55, 85.14, 71.35, 73.11]

# Values from the current APTOS dataset
train_aptos = [85.4, 87.7, 82.0, 83.7]
val_aptos = [78.5, 85.1, 80.8, 81.0]

# Bar width and positions
bar_width = 0.2
index = np.arange(len(metrics))

# Plotting the graph
plt.figure(figsize=(10, 6))

# Plot for previous dataset
plt.bar(index, train_previous, bar_width, label='Train (Previous)', color='blue')
plt.bar(index + bar_width, val_previous, bar_width, label='Validation (Previous)', color='orange')

# Plot for current APTOS dataset
plt.bar(index + 2 * bar_width, train_aptos, bar_width, label='Train (APTOS)', color='green')
plt.bar(index + 3 * bar_width, val_aptos, bar_width, label='Validation (APTOS)', color='red')

# Labels and titles
plt.xlabel('Metrics')
plt.ylabel('Percentage')
plt.title('Comparison of DenseNet121 Performance Metrics - Previous Dataset vs APTOS Dataset')
plt.xticks(index + 1.5 * bar_width, metrics)
plt.ylim([60, 100])  # Ensuring the graph scale is similar for better comparison
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example data
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']

# Data for the previous dataset
previous_train = [77.41, 87.78, 74.12, 76.84]
previous_val = [72.55, 85.14, 71.35, 73.11]

# Data for the APTOS dataset
aptos_train = [85.4, 87.7, 82.0, 83.7]
aptos_val = [78.5, 85.1, 80.8, 81.0]

# Bar width and positions
bar_width = 0.23
index = np.arange(len(metrics))

# Set the same color scheme for both datasets
train_color = '#0000FF'  # Blue
val_color = '#FFA500'    # Orange

# Plot bars
plt.bar(index, previous_train, bar_width, label='Previous - Training', color=train_color)
plt.bar(index + bar_width, previous_val, bar_width, label='Previous - Validation', color=val_color)

# Add APTOS dataset bars using the same color scheme
plt.bar(index, aptos_train, bar_width, alpha=0.5, color=train_color, label='APTOS - Training')
plt.bar(index + bar_width, aptos_val, bar_width, alpha=0.5, color=val_color, label='APTOS - Validation')

# Labels and title
plt.xlabel('Metrics')
plt.ylabel('Percentage')
plt.title('Model Performance Metrics - DenseNet-121')
plt.xticks(index + bar_width / 2, metrics)
plt.legend()
plt.ylim([60, 100])

# Show plot
plt.tight_layout()
plt.show()
