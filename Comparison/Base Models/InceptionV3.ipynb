# %%
import numpy as np
import matplotlib.pyplot as plt

# Metrics
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']

# Data for the previous dataset
previous_train = [92.82, 94.76, 91.34, 92.99]  # Max values from your previous dataset
previous_val = [74.50, 76.47, 71.06, 73.20]  # Max values from your previous dataset

# Data for the APTOS dataset
aptos_train = [87.47, 89.85, 86.27, 87.35]  # Max values from APTOS dataset
aptos_val = [76.65, 79.68, 74.18, 77.53]  # Max values from APTOS dataset

# Bar width and positions
bar_width = 0.23
index = np.arange(len(metrics))

# Set the color scheme for both datasets
train_color = '#0000FF'  # Blue
val_color = '#FFA500'    # Orange

# Plot bars
plt.bar(index, previous_train, bar_width, label='Previous - Training', color=train_color)
plt.bar(index + bar_width, previous_val, bar_width, label='Previous - Validation', color=val_color)

# Add APTOS dataset bars
plt.bar(index + bar_width*2, aptos_train, bar_width, alpha=0.5, color=train_color, label='APTOS - Training')
plt.bar(index + bar_width*3, aptos_val, bar_width, alpha=0.5, color=val_color, label='APTOS - Validation')

# Labels and title
plt.xlabel('Metrics')
plt.ylabel('Percentage')
plt.title('Model Performance Metrics Comparison')
plt.xticks(index + bar_width*1.5, metrics)
plt.legend()
plt.ylim([60, 100])

# Show plot
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example data
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']

# Data for the previous dataset
previous_train = [92.82, 94.76, 91.34, 92.99] 
previous_val = [74.50, 76.47, 71.06, 73.20]

# Data for the APTOS dataset
aptos_train = [87.47, 89.85, 86.27, 87.35]
aptos_val = [76.65, 79.68, 74.18, 77.53]

# Bar width and positions
bar_width = 0.23
index = np.arange(len(metrics))

# Set the same color scheme for both datasets
train_color = '#0000FF'  # Blue
val_color = '#FFA500'    # Orange

# Plot bars
plt.bar(index, previous_train, bar_width, label='Previous - Training', color=train_color)
plt.bar(index + bar_width, previous_val, bar_width, label='Previous - Validation', color=val_color)

# Add APTOS dataset bars using the same color scheme
plt.bar(index, aptos_train, bar_width, alpha=0.5, color=train_color, label='APTOS - Training')
plt.bar(index + bar_width, aptos_val, bar_width, alpha=0.5, color=val_color, label='APTOS - Validation')

# Labels and title
plt.xlabel('Metrics')
plt.ylabel('Percentage')
plt.title('Model Performance Metrics - InceptionV3')
plt.xticks(index + bar_width / 2, metrics)
plt.legend()
plt.ylim([60, 100])

# Show plot
plt.tight_layout()
plt.show()
