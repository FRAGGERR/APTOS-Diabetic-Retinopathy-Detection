# %%
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Metrics
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
# Data generators with rescaling
train_datagen_with_aug = ImageDataGenerator(rescale=1./255, validation_split=0.1)

train_generator = train_datagen_with_aug.flow_from_directory(
    r"C:\Users\Hardik\Desktop\DR\Dataset\aptos2019-blindness-detection\train_split",
    target_size=(224, 224),  # Resize images to a fixed size
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen_with_aug.flow_from_directory(
    r"C:\Users\Hardik\Desktop\DR\Dataset\aptos2019-blindness-detection\train_split",
    target_size=(224, 224),  # Resize images to a fixed size
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 3298 images belonging to 5 classes.
# Found 364 images belonging to 5 classes.

# %%
# Functional API for building the model
input_img = Input(shape=(224, 224, 3))
InceptionV3 = InceptionV3(weights='imagenet', include_top=False, input_tensor=input_img)

# Freeze layers in DenseNet121
for layer in InceptionV3.layers:
    layer.trainable = False

# Add custom layers on top of DenseNet121
x = Flatten()(InceptionV3.output)
x = Dropout(0.2)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(512, activation='relu')(x)
output = Dense(5, activation='softmax')(x)

# Construct the model
model = Model(inputs=input_img, outputs=output)

# Summary of the model
# model.summary()

# Compile the model
adam = Adam(learning_rate=0.001)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy', precision_m, recall_m, f1_m])

# Train the model
graph = model.fit(train_generator, epochs=25, validation_data=validation_generator)

# # Save the model
# model.save("/Users/hardikchhipa/Desktop/DR-Arvind/saved_models/used_models/densenet_121.h5")

# Print the results
print(graph.history)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step
# Epoch 1/25
# c:\Users\Hardik\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 311s 3s/step - accuracy: 0.5247 - f1_m: 0.5144 - loss: 14.2120 - precision_m: 0.5240 - recall_m: 0.5080 - val_accuracy: 0.7445 - val_f1_m: 0.7390 - val_loss: 0.7927 - val_precision_m: 0.7695 - val_recall_m: 0.7118
# Epoch 2/25
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 297s 3s/step - accuracy: 0.7355 - f1_m: 0.7335 - loss: 0.7719 - precision_m: 0.7972 - recall_m: 0.6817 - val_accuracy: 0.7280 - val_f1_m: 0.7139 - val_loss: 0.7165 - val_precision_m: 0.7990 - val_recall_m: 0.6467
# Epoch 3/25
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 303s 3s/step - accuracy: 0.7754 - f1_m: 0.7704 - loss: 0.6339 - precision_m: 0.8374 - recall_m: 0.7160 - val_accuracy: 0.7280 - val_f1_m: 0.6951 - val_loss: 0.7312 - val_precision_m: 0.8033 - val_recall_m: 0.6155
# Epoch 4/25
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 297s 3s/step - accuracy: 0.7511 - f1_m: 0.7448 - loss: 0.6471 - precision_m: 0.8283 - recall_m: 0.6810 - val_accuracy: 0.7335 - val_f1_m: 0.7051 - val_loss: 0.7116 - val_precision_m: 0.8288 - val_recall_m: 0.6163
# Epoch 5/25
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 288s 3s/step - accuracy: 0.7593 - f1_m: 0.7632 - loss: 0.6022 - precision_m: 0.8432 - recall_m: 0.6999 - val_accuracy: 0.7473 - val_f1_m: 0.7583 - val_loss: 0.7111 - val_precision_m: 0.7996 - val_recall_m: 0.7222
# Epoch 6/25
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 285s 3s/step - accuracy: 0.7482 - f1_m: 0.7499 - loss: 0.6565 - precision_m: 0.8254 - recall_m: 0.6899 - val_accuracy: 0.7582 - val_f1_m: 0.7330 - val_loss: 0.6750 - val_precision_m: 0.8374 - val_recall_m: 0.6536
# Epoch 7/25
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 288s 3s/step - accuracy: 0.7667 - f1_m: 0.7586 - loss: 0.6412 - precision_m: 0.8374 - recall_m: 0.6975 - val_accuracy: 0.7555 - val_f1_m: 0.7502 - val_loss: 0.7468 - val_precision_m: 0.7844 - val_recall_m: 0.7196
# Epoch 8/25
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 300s 3s/step - accuracy: 0.8107 - f1_m: 0.8135 - loss: 0.5118 - precision_m: 0.8679 - recall_m: 0.7673 - val_accuracy: 0.7473 - val_f1_m: 0.7248 - val_loss: 0.7083 - val_precision_m: 0.7963 - val_recall_m: 0.6667
# Epoch 9/25
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 290s 3s/step - accuracy: 0.8179 - f1_m: 0.8197 - loss: 0.4730 - precision_m: 0.8848 - recall_m: 0.7661 - val_accuracy: 0.7527 - val_f1_m: 0.7516 - val_loss: 0.7018 - val_precision_m: 0.8149 - val_recall_m: 0.6997
# Epoch 10/25
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 286s 3s/step - accuracy: 0.8221 - f1_m: 0.8069 - loss: 0.4873 - precision_m: 0.8826 - recall_m: 0.7459 - val_accuracy: 0.7665 - val_f1_m: 0.7725 - val_loss: 0.8213 - val_precision_m: 0.7893 - val_recall_m: 0.7569
# Epoch 11/25
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 267s 2s/step - accuracy: 0.8051 - f1_m: 0.8098 - loss: 0.5181 - precision_m: 0.8839 - recall_m: 0.7507 - val_accuracy: 0.7253 - val_f1_m: 0.7257 - val_loss: 0.7775 - val_precision_m: 0.7819 - val_recall_m: 0.6788
# Epoch 12/25
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 277s 3s/step - accuracy: 0.8244 - f1_m: 0.8243 - loss: 0.4467 - precision_m: 0.8877 - recall_m: 0.7724 - val_accuracy: 0.7527 - val_f1_m: 0.7213 - val_loss: 0.6829 - val_precision_m: 0.8752 - val_recall_m: 0.6189
# Epoch 13/25
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 261s 2s/step - accuracy: 0.8537 - f1_m: 0.8357 - loss: 0.4138 - precision_m: 0.9144 - recall_m: 0.7730 - val_accuracy: 0.7363 - val_f1_m: 0.6578 - val_loss: 0.7929 - val_precision_m: 0.8736 - val_recall_m: 0.5295
# Epoch 14/25
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 267s 2s/step - accuracy: 0.8236 - f1_m: 0.7688 - loss: 0.5254 - precision_m: 0.9054 - recall_m: 0.6780 - val_accuracy: 0.7527 - val_f1_m: 0.7477 - val_loss: 0.8295 - val_precision_m: 0.7796 - val_recall_m: 0.7196
# Epoch 15/25
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 270s 2s/step - accuracy: 0.8346 - f1_m: 0.8309 - loss: 0.4858 - precision_m: 0.8544 - recall_m: 0.8093 - val_accuracy: 0.6951 - val_f1_m: 0.7021 - val_loss: 1.0145 - val_precision_m: 0.7336 - val_recall_m: 0.6745
# Epoch 16/25
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 274s 2s/step - accuracy: 0.8301 - f1_m: 0.8160 - loss: 0.5097 - precision_m: 0.8421 - recall_m: 0.7922 - val_accuracy: 0.7555 - val_f1_m: 0.7654 - val_loss: 0.7574 - val_precision_m: 0.7974 - val_recall_m: 0.7370
# Epoch 17/25
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8542 - f1_m: 0.8566 - loss: 0.4536 - precision_m: 0.8746 - recall_m: 0.8397 - val_accuracy: 0.7582 - val_f1_m: 0.7596 - val_loss: 0.7735 - val_precision_m: 0.7803 - val_recall_m: 0.7405
# Epoch 18/25
# 104/104 ━━━━━━━━━━━━━━━━━━━━
032157898, 0.6610711216926575, 0.5171899795532227, 0.48755231499671936, 0.5154556035995483, 0.4977025091648102, 0.45526546239852905, 0.39430558681488037, 0.5159835815429688, 0.49374210834503174, 0.47602447867393494, 0.46014776825904846, 0.42413634061813354, 0.41636449098587036, 0.3781726658344269, 0.3796708881855011, 0.39310988783836365, 0.35208043456077576, 0.3374588191509247, 0.3740205466747284], 'precision_m': [0.6156577467918396, 0.7864037752151489, 0.8183374404907227, 0.8224060535430908, 0.8371217250823975, 0.8211910724639893, 0.8301726579666138, 0.8672084808349609, 0.8799397945404053, 0.8624354600906372, 0.8867194056510925, 0.8907155394554138, 0.9052727818489075, 0.8767833709716797, 0.8514372706413269, 0.8593425750732422, 0.8695065975189209, 0.8786067962646484, 0.8872301578521729, 0.8891869783401489, 0.8899850249290466, 0.8875051736831665, 0.8974797129631042, 0.9065903425216675, 0.8930383324623108], 'recall_m': [0.5766226053237915, 0.671875, 0.7052283883094788, 0.6887019276618958, 0.6893028616905212, 0.6808894276618958, 0.6902043223381042, 0.7563101053237915, 0.7650240659713745, 0.7349759340286255, 0.7566105723381042, 0.7734375, 0.7836538553237915, 0.7385817170143127, 0.8052884340286255, 0.8121995329856873, 0.8344351053237915, 0.8464543223381042, 0.8419471383094788, 0.8626803159713745, 0.8608773946762085, 0.862379789352417, 0.8777043223381042, 0.889723539352417, 0.87109375], 'val_accuracy': [0.7445054650306702, 0.7280219793319702, 0.7280219793319702, 0.7335164546966553, 0.7472527623176575, 0.7582417726516724, 0.7554945349693298, 0.7472527623176575, 0.7527472376823425, 0.7664835453033447, 0.7252747416496277, 0.7527472376823425, 0.7362637519836426, 0.7527472376823425, 0.6950549483299255, 0.7554945349693298, 0.7582417726516724, 0.7252747416496277, 0.7335164546966553, 0.75, 0.7527472376823425, 0.7445054650306702, 0.75, 0.7417582273483276, 0.7252747416496277], 'val_f1_m': [0.7390286922454834, 0.7139358520507812, 0.6951320767402649, 0.705149233341217, 0.7582545280456543, 0.7329504489898682, 0.7501659989356995, 0.7247757911682129, 0.7515840530395508, 0.7724745273590088, 0.7257464528083801, 0.7213016152381897, 0.65781170129776, 0.7476861476898193, 0.7020537257194519, 0.7653566002845764, 0.7596281170845032, 0.7172592282295227, 0.7321900725364685, 0.7419797778129578, 0.7554849982261658, 0.7517290711402893, 0.7453474402427673, 0.7482144832611084, 0.7359144687652588], 'val_loss': [0.7927285432815552, 0.7165111303329468, 0.731242835521698, 0.7115876078605652, 0.7111115455627441, 0.674980103969574, 0.746779203414917, 0.7082577347755432, 0.7017653584480286, 0.821262001991272, 0.7774658203125, 0.6828855872154236, 0.7928955554962158, 0.829541027545929, 1.014477014541626, 0.7574083209037781, 0.7734833359718323, 1.011085033416748, 0.7778220772743225, 0.751668393611908, 0.873080849647522, 0.8515892624855042, 0.8739432096481323 ...

# %%
import matplotlib.pyplot as plt

fig1 = plt.gcf()

plt.plot(graph.history['accuracy'])
plt.plot(graph.history['val_accuracy'])

# plt.axis(ymin=0.4, ymax=1)
plt.grid()

plt.title('DenseNet201 Accuracy for DR Dataset')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train','validation'])

plt.show()

# %%
import matplotlib.pyplot as plt

fig1 = plt.gcf()

plt.plot(graph.history['loss'])
plt.plot(graph.history['val_loss'])

# plt.axis(ymin=0.4, ymax=1)
plt.grid()

plt.title('DenseNet201 Loss for DR Dataset')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train','validation'])

plt.show()
